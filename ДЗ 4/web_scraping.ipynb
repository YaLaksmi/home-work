# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга"

# %% [markdown]
# ## Обязательная часть

# %% [markdown]
# Вам необходимо написать функцию, которая будет основана на **поиске** по сайту [habr.com](https://habr.com/ru/search/).
# Функция в качестве параметра должна принимать **список** запросов для поиска (например, `['python', 'анализ данных']`) и на основе материалов, попавших в результаты поиска по **каждому** запросу, возвращать датафрейм вида:
#
# ```
# <дата> - <заголовок> - <ссылка на материал>
# ```
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %% [markdown]
# ## Дополнительная часть (необязательная)

# %% [markdown]
# Функция из обязательной части задания должна быть расширена следующим образом:
# - кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента `4` необходимо получить материалы с первых 4 страниц результатов;
# - в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# ```
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>
# ```

# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd

# def search_habr(queries):
#     base_url = "https://habr.com"
#     search_url = "https://habr.com/ru/search/"
#     articles = set()  # Используем множество для устранения дубликатов

#     results = []

#     for query in queries:
#         params = {'q': query}
#         response = requests.get(search_url, params=params)
#         soup = BeautifulSoup(response.text, 'html.parser')
        
#         # Найти все статьи на странице
#         for article in soup.find_all('article', class_='tm-articles-list__item'):
#             date_tag = article.find('time')
#             title_tag = article.find('a', class_='tm-article-snippet__title-link')
            
#             if date_tag and title_tag:
#                 date = date_tag['datetime'][:10]  # Получаем дату в формате YYYY-MM-DD
#                 title = title_tag.text.strip()
#                 link = base_url + title_tag['href']
                
#                 # Убедиться, что статья уникальна
#                 if link not in articles:
#                     articles.add(link)
#                     results.append([date, title, link])
    
#     # Создание датафрейма
#     df = pd.DataFrame(results, columns=['Дата', 'Заголовок', 'Ссылка'])
    
#     return df

# # Пример использования
# queries = ['python', 'анализ данных']
# df = search_habr(queries)
# print(df)
# Out:
# Empty DataFrame
# Columns: [Дата, Заголовок, Ссылка]
# Index: []

# %%
res = requests.get('https://habr.com/en/search/')
# res
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n  <title>Search results for «» &#x2F; Habr</title>\n<link rel="image_src" href="/img/habr_en.png" data-hid="2a79c45">\n<link href="https://habr.com/en/search/" rel="canonical" data-hid="e3fa780">\n<meta itemprop="image" content="/img/habr_en.png">\n<meta property="og:image" content="/img/habr_en.png">\n<meta property="og:image:width" content="1200">\n<meta property="og:image:height" content="630">\n<meta property="aiturec:image" content="/img/habr_en.png">\n<meta name="twitter:image" content="/img/habr_en.png">\n<meta property="vk:image" content="/img/habr_en.png?format=vk">\n<meta property="fb:app_id" content="444736788986613">\n<meta property="fb:pages" content="472597926099084">\n<meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="@habr_eng">\n<meta property="og:locale" content="en_US">\n<meta property="og:type" content="website">\n<meta property="og:site_name" content="Habr">\n<meta property="og:
# ...
